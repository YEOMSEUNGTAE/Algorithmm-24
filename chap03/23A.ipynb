# %% [markdown]
# 1)인접 행렬로 표현하라.
# in =
# [
# A[0,1,0,1,1,0,0],
# B[1,0,1,0,1,1,0],
# C[0,1,0,0,0,0,1],
# D[1,0,0,0,1,0,0],
# E[1,1,0,1,0,0,0],
# F[0,1,0,0,0,0,1],
# G[0,0,1,0,0,1,0],
# ]

# %% [markdown]
# 2)인접 리스트로 표현하라.
# g = {
#     'A':{'B','D','C'},
#     'B':{'A','C','E','F'},
#     'C':{'B','G'},
#     'D':{'A','E'},
#     'E':{'A','B','D'},
#     'F':{'B','G'},
#     'G':{'C','F'},
# }

# %% [markdown]
# 3)정점 A를 출발 정점으로 하고 깊이 우선 방식으로 탐색 했을때 방문하는 정점을 순서대로 나열하여라. 단 인접한 정점들 중에서는 알파벳으로 먼저 나오는 정점을 먼저 탐색한다고 가정하라.
#
# A->B->C->G->F->E->D

# %% [markdown]
# 4)위 문제에서 더 이상 방문 하지 않는 인접 방식으로 탐색하였을때 첫번째로 되돌아가는 정점을 찾아라.
#
# G

# %% [markdown]
# 5)정점 A를 출발 정점으로 하고 너비 우선 방식으로 탐색하였을때 방문하는 정점을 순서대로 나열하라. 인접한 정점들 중에서는 알파벳으로 먼저 나오는 정점을 큐에 먼저 넣는다고 가정하라.
#
# A->B->D->E->C->F->G
