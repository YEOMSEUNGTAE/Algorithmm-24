# %% [markdown]
# ### 01.문제 정의
# 정렬된 2개의 리스트를 병합하여 병합 결과를 임시 리스트 안에 저장하는 문제이다.

# %% [markdown]
# ### 02.알고리즘 설명
# 각 리스트의 첫번째 항목부터 오른쪽으로 시작, 두 리스트의 항목A[i]와 A[j]를 비교하여 더 작은 항목 먼저 새로운 리스트에 복사한다.
# A[i] > A[j]인 경우 A[j]를 복사하여 인덱스 j와 임시 리시트의 인덱스k를 증가
# A[i] <= A[j]인 경우 A[i]를 암시 리스트 sorted[k]로 복사한 후 i와 k를 증가
# 다른 리스트의 남은 항목들은 모두 c로 복사

# %% [markdown]
# ### 03.손으로 푼 예제

# %% [markdown]
# ![KakaoTalk_20240501_001448929.jpg](attachment:KakaoTalk_20240501_001448929.jpg)

# %% [markdown]
# ### 04.코드 개요
# ##### 함수명:merge(A, left, mid, right) , merge_sort(A, left, right)
# ##### 입력 값:data = [5, 3, 8, 4, 9, 1, 6, 2, 7]
# ##### 출력 값:print("Original:", data), print(:"MergeSort:",data)

# %% [markdown]
# ### 05.코드

# %%
def merge(A,left,mid,right):
    k = left
    i = left
    j = mid + 1
    while i<=mid and j<=right:
        if A[i] <= A[j]:
            sorted[k] = A[i]
            i, k = i+1, k+1
        else:
            sorted[k] = A[j]
            j, k = j+1, k+1

    if i > mid:
        sorted[k:k+right-j+1] = A[j:right+1]
    else:
        sorted[k:k+mid-i+1] = A[i:mid+1]

    A[left:right+1] = sorted[left:right+1]

# %% [markdown]
# ### 06.테스트 코드

# %%
def merge_sort(A, left, right):
    if left < right:
        mid = (left + right) // 2
        merge_sort(A, left, mid)
        merge_sort(A, mid + 1, right) 
        merge(A, left, mid, right) 

def merge(A, left, mid, right):
    k = left
    i = left
    j = mid + 1
    while i <= mid and j <= right:
        if A[i] <= A[j]:
            sorted[k] = A[i]
            i, k = i + 1, k + 1
        else:
            sorted[k] = A[j]
            j, k = j + 1, k + 1

    if i > mid:
        sorted[k:k + right - j + 1] = A[j:right + 1]
    else:
        sorted[k:k + mid - i + 1] = A[i:mid + 1]

    A[left:right + 1] = sorted[left:right + 1]

data = [5, 3, 8, 4, 9, 1, 6, 2, 7]
sorted = [0] * len(data)
print("원본 리스트:", data)
merge_sort(data, 0, len(data) - 1)
print("합병 정렬 결과:", data)

# %% [markdown]
# ### 07.수행결과

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 08.복잡도 분석
# O(n log 2n)

# %% [markdown]
# ### 09.협력 내용

# %% [markdown]
# 팀원들과 모르는 부분이 있으면 함께 고민하여 해결함
