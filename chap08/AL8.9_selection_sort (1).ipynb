# %% [markdown]
# #### 1) 문제 정의 (MD)

# %% [markdown]
# 허프만 트리 생성 알고리즘

# %% [markdown]
# #### 2) 알고리즘 설명  (MD)

# %% [markdown]
# <허프만 트리를 만드는 알고리즘>
# 1. 트리 중에서 루트 값이 가장 작은 트리 2개를 반복적으로 찾아야 한다.
# 2. (우선순위 큐 이용) 항목을 넣은 순서와 상관없이 꺼낼 때에는 항상 우선순위가 가장 높은 항목을 먼저 꺼낸다.
# 3. (우선순위 큐를 구현하는 가장 효율적인 방법) 힙 트리를 사용하는 것

# %% [markdown]
# ####  3) 손으로 푼 예제 (MD, 이미지 삽입)

# %% [markdown]
# ![염승태][![image.png](attachment:image.png)]

# %% [markdown]
# #### 4) 알고리즘 개요(입력 변수, 출력, 알고리즘 개요) (MD)

# %% [markdown]
# ##### 함수명: make_heap_tree(freq, label)
# ##### 입력 변수: freq, label
# ##### 출력: heapq.heappop(h)-(최종 트리의 루트 출력)

# %% [markdown]
# #### 5) 알고리즘 코드 (PY,C)

# %%
import heapq

def make_heap_tree(freq, label):
    n = len(freq)
    h = []
    for i in range(n):
        heapq.heappush(h, (freq[i], label[i]))

    for i in range(1, n):
        e1 = heapq.heappop(h)
        e2 = heapq.heappop(h)
        heapq.heappush(h, (e1[0] + e2[0], e1[1] + e2[1]))
        print(e1, "+", e2)

    print(h)

# %% [markdown]
# #### 6) 테스트 코드  (PY,C) , 입력을 바꾸어서

# %%
label = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
freq = [24, 3, 8, 10, 33, 6, 4, 12]
make_heap_tree(freq, label)
# Out:
# (3, 'B') + (4, 'G')
# (6, 'F') + (7, 'BG')
# (8, 'C') + (10, 'D')
# (12, 'H') + (13, 'FBG')
# (18, 'CD') + (24, 'A')
# (25, 'HFBG') + (33, 'E')
# (42, 'CDA') + (58, 'HFBGE')
# [(100, 'CDAHFBGE')]

# %% [markdown]
# #### 7) 수행 결과 (MD, 결과 캡춰하여 이미지로 삽입)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 8) 복잡도 분석

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 9) 조별 협력 내용 (상호 지도)

# %% [markdown]
# 실습시간 중 이해가 되지 않는 부분에 대해 팀원들과 모여 상의하며 문제를 해결해 나아갔습니다.
