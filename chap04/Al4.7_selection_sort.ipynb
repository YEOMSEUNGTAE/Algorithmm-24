# %% [markdown]
# ### 01.문제 정의
# 억지기법을 사용하여 거듭제곱을 구하는 문제

# %% [markdown]
# ### 02.알고리즘 설명
# 주어진 X의 n 제곱을 계산하여 출력하는 코드로 이 코드에는 **연산자를 사용하지 않고 루프를 사용하여 각각의 값을 계산하는 억지기법이 사용된 알고리즘이다.

# %% [markdown]
# ### 03.손으로 푼 예제

# %% [markdown]
# ![김민성][![4.7 al.jpg](<attachment:4.7 al.jpg>)]

# %% [markdown]
# ### 04.코드개요
# ##### 함수명 : slow_power
# ##### 입력 : x(거듭제곱의 밑이 되는 숫자),n(거듭제곱의 지수)
# ##### 반환값 : slow_power 함수에서 계산한 거듭제곱의 결과
# ## 함수 설명:
# ##### 1행. slow_power 함수에 x와n이라는 두 개의 매개변수를 받아들임
# ##### 2행. 변수 'result' 초기화
# ##### 3행. n번 반복하는 for 루프를 설정 i는 0~n-1까지의 값을 가짐
# ##### 4행. x를 n번 곱하여 계산, result 변수에 결과를 저장
# ##### 5행. result에 저장된 거듭제곱 값을 반환

# %% [markdown]
# ### 05.코드

# %%
def slow_power(x, n):
    result = 1.0
    for i in range(n):
        result = result * x
    return result

# %% [markdown]
# ### 06. 테스트 코드

# %%
def slow_power(x, n):
    result = 1.0
    for i in range(n):
        result = result * x
    return result

x = 2
n = 10
print(slow_power(x, n))

# %% [markdown]
# ### 07. 수행 결과
# i[김민성][![4.7 실행결과.png](<attachment:4.7 실행결과.png>)]

# %% [markdown]
# ### 08. 복잡도 분석
# O(n), n번 반복하면서 x를 n번 곱하기 때문에 입력값 n에 비례하는 복잡도를 가진다.

# %% [markdown]
# ### 09. 협력 내용
# 팀원들과 모르는 부분이 있으면 함께 고민하여 문제를 해결했다.
