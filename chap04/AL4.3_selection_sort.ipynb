# %% [markdown]
# ## 01. 문제 정의
# 정렬 되지 않은 부분을 왼쪽 항과 비교하여 한칸씩 이동 후 정렬하는 문제

# %% [markdown]
# ## 02. 알고리즘 설명
# 두 번째 항부터 시작하여 왼쪽(앞) 항과 비교하여 삽입할 위치를 지정한 후 자료를 뒤로 옮기고 지정한 자리에 자료를 삽입하여 정렬하는 알고리즘이다.

# %% [markdown]
# ## 03. 손으로 푼 예제

# %% [markdown]
# i[김민성][![KakaoTalk_20240418_212318261.jpg](attachment:KakaoTalk_20240418_212318261.jpg)]

# %% [markdown]
# ## 04. 코드개요
# #### 함수명 : insertion_sort
# #### 입력 : data = [5, 3, 8, 4, 9, 1, 6, 2, 7]
# #### 반환값 : 반환값은 따로 없고 정렬된 요소를 출력합니다
# #### 함수 설명 :
# #### 1~2행.정렬할 리스트 A를 입력 후 리스트 A의 길이를 변수 n에 할당한다.
# #### 3~4행.1부터 n-1까지 순차적으로 반복하는 루프를 생성 후 A[i]를 key에 저장한다.
# #### 5~6행.항목 A[i-1]부터 감사 실시 하여 A[i-1]부터 왼쪽으로 비교를 진행 key의 값보다 크면 반복
# #### 7~8행.항목들을 오른쪽으로 한 칸씩 이동하고 위치를 왼쪽으로 이동
# #### 9행.항목A[i]를 제 위치에 삽입

# %% [markdown]
# ## 05. 코드

# %%
def insertion_sort(A):
    n = len(A)
    for i in range(1, n):
        key = A[i]
        j = i - 1
        while j >= 0 and A[j] > key:
            A[j + 1] = A[j]
            j = j - 1
        A[j + 1] = key
        printStep(A, i)

# %% [markdown]
# ## 06. 테스트 코드

# %%
def printStep(arr, val):
    print("step %d =" % val, end=' ')
    print(arr)

def insertion_sort(A):
    n = len(A)
    for i in range(1, n):
        key = A[i]
        j = i - 1
        while j >= 0 and A[j] > key:
            A[j + 1] = A[j]
            j = j - 1
        A[j + 1] = key
        printStep(A, i)

data = [5, 3, 8, 4, 9, 1, 6, 2, 7]
print("Original:", data)
insertion_sort(data)
print("Insertion:", data)

# %% [markdown]
# ## 07. 수행결과

# %% [markdown]
# ![김민성][![알고리즘 4.3 결과.png](<attachment:알고리즘 4.3 결과.png>)]

# %% [markdown]
# ## 08.복잡도 분석
# 리스트가 정렬되지 않았기 때문에 내부 루프가 i번 반복되므로 기본 연산이 i번 실행된다.
# 따라서 복잡도는 o(n^2)이다.

# %% [markdown]
# ## 09. 협력 내용

# %% [markdown]
# 팀원과 모르는 부분이 있으면 같이 해결함
